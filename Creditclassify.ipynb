# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
dataset_credit = pd.read_csv('creditcard.csv')

# %%
print (dataset_credit.shape)
# Out:
# (284807, 31)

# %%
dataset_credit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
for n in range(3):
    print(n)
# Out:
# 0
# 1
# 2

# %%
print(dataset_credit.columns)
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
#        'class'],
#       dtype='object')

# %%
#changing the columns to appropiate name
dataset_credit.rename(columns= {"Unnamed: 0":"ID"}, inplace=True)
dataset_credit.rename(columns= {"class":"target"}, inplace=True)

# %%
# changing the columns name in lower and replacing "-"  to ""

columnsclean=[]
for i in range(len(dataset_credit.columns)):
    columnsclean.append(dataset_credit.columns[i].replace("-","").lower())
dataset_credit.columns=columnsclean

# %%
dataset_credit.describe()
# Out:
#                 time            v1            v2            v3            v4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  v5            v6            v7            v8            v9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
dataset_credit[dataset_credit.columns[1:]].median()
# Out:
# v1         0.018109
# v2         0.065486
# v3         0.179846
# v4        -0.019847
# v5        -0.054336
# v6        -0.274187
# v7         0.040103
# v8         0.022358
# v9        -0.051429
# v10       -0.092917
# v11       -0.032757
# v12        0.140033
# v13       -0.013568
# v14        0.050601
# v15        0.048072
# v16        0.066413
# v17       -0.065676
# v18       -0.003636
# v19        0.003735
# v20       -0.062481
# v21       -0.029450
# v22        0.006782
# v23       -0.011193
# v24        0.040976
# v25        0.016594
# v26       -0.052139
# v27        0.001342
# v28        0.011244
# amount    22.000000
# class      0.000000
# dtype: float64

# %%
dataset_credit[dataset_credit.columns[1:]].mean()
# Out:
# v1        3.919560e-15
# v2        5.688174e-16
# v3       -8.769071e-15
# v4        2.782312e-15
# v5       -1.552563e-15
# v6        2.010663e-15
# v7       -1.694249e-15
# v8       -1.927028e-16
# v9       -3.137024e-15
# v10       1.768627e-15
# v11       9.170318e-16
# v12      -1.810658e-15
# v13       1.693438e-15
# v14       1.479045e-15
# v15       3.482336e-15
# v16       1.392007e-15
# v17      -7.528491e-16
# v18       4.328772e-16
# v19       9.049732e-16
# v20       5.085503e-16
# v21       1.537294e-16
# v22       7.959909e-16
# v23       5.367590e-16
# v24       4.458112e-15
# v25       1.453003e-15
# v26       1.699104e-15
# v27      -3.660161e-16
# v28      -1.206049e-16
# amount    8.834962e+01
# class     1.727486e-03
# dtype: float64

# %%
dataset_credit.isnull().sum()
# Out:
# time      0
# v1        0
# v2        0
# v3        0
# v4        0
# v5        0
# v6        0
# v7        0
# v8        0
# v9        0
# v10       0
# v11       0
# v12       0
# v13       0
# v14       0
# v15       0
# v16       0
# v17       0
# v18       0
# v19       0
# v20       0
# v21       0
# v22       0
# v23       0
# v24       0
# v25       0
# v26       0
# v27       0
# v28       0
# amount    0
# target    0
# dtype: int64

# %%
total_len = len(dataset_credit["target"])
percentage_total = (dataset_credit.target.value_counts()/total_len)*100
percentage_total
# Out:
# 0    99.827251
# 1     0.172749
# Name: target, dtype: float64

# %%
sb.countplot(dataset_credit.target.set_title("Disturbution pattern")
ax = plt.gca()
#print (ax)
for p in ax.patches:
    height = p.get_height()
    #print(height)
    ax.text(p.get_x() + p.get_width()/2,
           height + 2,
           '{:.2f}%'.format(100*(height/total_len)),
            fontsize =14, ha='center' ,va ='bottom')
    sb.set(font_scale=1)
    ax.set_xlabel('Target')
    ax.set_ylabel('No of records')
    plt.xticks(rotation=90)
# Out:
#   File "<ipython-input-43-ad3e01c3edf9>", line 2
#     ax = plt.gca()
#      ^
# SyntaxError: invalid syntax

# %%
x = dataset_credit.columns
y = dataset_credit.isnull().sum()
sb.barplot(x,y)
ax = plt.gca()
#print (ax)
for ax in ax.patches:
    height = p.get_height()
    #print (p.get_width)
    #ax.text(p.get_x() + p.get_width()/2,
            #height + 2,
            #int(height),
            #fontsize=13 , ha='center', va='bottom')
#ax.set_xlabel('Columns')
#ax.set_ylabel('No.of blank records')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2774042efa5f> in <module>()
#       5 #print (ax)
#       6 for ax in ax.patches:
# ----> 7     height = p.get_height()
#       8     #print (p.get_width)
#       9     #ax.text(p.get_x() + p.get_width()/2,
#
# NameError: name 'p' is not defined

# %%
training_dataset_addmissingval=training_dataset.fillna((training_dataset.mean()))

# %%
training_dataset_addmissingval.isnull().sum()
# Out:
# id                                      0
# seriousdlqin2yrs                        0
# revolvingutilizationofunsecuredlines    0
# age                                     0
# numberoftime3059dayspastduenotworse     0
# debtratio                               0
# monthlyincome                           0
# numberofopencreditlinesandloans         0
# numberoftimes90dayslate                 0
# numberrealestateloansorlines            0
# numberoftime6089dayspastduenotworse     0
# numberofdependents                      0
# dtype: int64

# %%
training_dataset_addmissingval[training_dataset_addmissingval.columns[1:]].corr()
# Out:
#                                       seriousdlqin2yrs  \
# seriousdlqin2yrs                              1.000000
# revolvingutilizationofunsecuredlines         -0.001802
# age                                          -0.115386
# numberoftime3059dayspastduenotworse           0.125587
# debtratio                                    -0.007602
# monthlyincome                                -0.018002
# numberofopencreditlinesandloans              -0.029669
# numberoftimes90dayslate                       0.117175
# numberrealestateloansorlines                 -0.007038
# numberoftime6089dayspastduenotworse           0.102261
# numberofdependents                            0.045621
#
#                                       revolvingutilizationofunsecuredlines  \
# seriousdlqin2yrs                                                 -0.001802
# revolvingutilizationofunsecuredlines                              1.000000
# age                                                              -0.005898
# ...

# %%
sb.set()
sb.heatmap(training_dataset_addmissingval[training_dataset_addmissingval.columns[1:]].corr(),annot=True,fmt='.01f',
          cmap=(sb.cubehelix_palette(8,start=.3,rot=.75)))
plt.show()

# %%
#Finding outliers
# to do deep analysisb

# %%
import collections

# %%
collections.Counter(training_dataset_addmissingval.age)
# Out:
# Counter({45: 3502,
#          40: 3093,
#          38: 2631,
#          30: 1937,
#          49: 3837,
#          74: 1451,
#          57: 3375,
#          39: 2987,
#          27: 1338,
#          51: 3627,
#          46: 3714,
#          76: 1183,
#          64: 3058,
#          78: 1054,
#          53: 3648,
#          43: 3208,
#          25: 953,
#          32: 2050,
#          58: 3443,
#          50: 3753,
#          69: 1954,
#          24: 816,
#          28: 1560,
#          62: 3568,
#          42: 3082,
#          75: 1241,
#          26: 1193,
#          52: 3609,
#          41: 3122,
#          81: 774,
#          31: 2038,
#          68: 2235,
#          70: 1777,
#          73: 1520,
#          29: 1702,
#          55: 3416,
#          35: 2246,
#          72: 1649,
#          60: 3258,
#          67: 2503,
#          36: 2379,
#          56: 3589,
#          37: 2521,
#          66: 2494,
#          83: 512,
#          34: 2155,
#          44: 3294,
# ...

# %%
# Finding the features

from sklearn.ensemble import RandomForestClassifier

# %%
training_dataset_addmissingval.columns[1:]
# Out:
# Index(['seriousdlqin2yrs', 'revolvingutilizationofunsecuredlines', 'age',
#        'numberoftime3059dayspastduenotworse', 'debtratio', 'monthlyincome',
#        'numberofopencreditlinesandloans', 'numberoftimes90dayslate',
#        'numberrealestateloansorlines', 'numberoftime6089dayspastduenotworse',
#        'numberofdependents'],
#       dtype='object')

# %%
X = training_dataset_addmissingval.drop(columns='seriousdlqin2yrs', axis=1)
y = training_dataset_addmissingval.seriousdlqin2yrs
feature_label = training_dataset_addmissingval.columns[1:]
forest = RandomForestClassifier (n_estimators=10000 , random_state=0 , n_jobs=-1)
forest.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-c84fec2a4eb1> in <module>()
#       4 forest = RandomForestClassifier (n_estimators=10000 , random_state=0 , n_jobs=-1)
#       5 forest.fit(X,y)
# ----> 6 importances = forest.feature_importances_b
#       7 indices = np.argsort(importances)[::-1]
#       8 for i in range(X.shape[1]):
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'feature_importances_b'

# %%
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for i in range(X.shape[1]):
    print ("%2d) %-*s %f" % (i + 1, 30, feature_label[i], importances[indices[i]]))
# Out:
#  1) seriousdlqin2yrs               0.164798
#  2) revolvingutilizationofunsecuredlines 0.145410
#  3) age                            0.141621
#  4) numberoftime3059dayspastduenotworse 0.116978
#  5) debtratio                      0.104838
#  6) monthlyincome                  0.088299
#  7) numberofopencreditlinesandloans 0.075687
#  8) numberoftimes90dayslate        0.048372
#  9) numberrealestateloansorlines   0.046667
# 10) numberoftime6089dayspastduenotworse 0.037553
# 11) numberofdependents             0.029777

# %%
plt.title('Importance features')
plt.bar(range(X.shape[1]),importances[indices], color='green', align='center')
plt.xticks(range(X.shape[1]), feature_label , rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
X = training_dataset_addmissingval.drop(columns='seriousdlqin2yrs' , axis=1)
y = training_dataset_addmissingval.seriousdlqin2yrs
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=20000)

# %%
logisticmdl = LogisticRegression()
logisticmdl.fit(X_train,y_train)
y_pred = logisticmdl.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9306933333333334

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[34858,    33],
#        [ 2566,    43]])

# %%
print (classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96     34891
#           1       0.57      0.02      0.03      2609
#
# avg / total       0.91      0.93      0.90     37500
